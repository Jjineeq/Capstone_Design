# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df_industrial = pd.read_csv('C:/Users/User/github/G_Capstone_Design/public_data/Industrial_data.csv',encoding='cp949')
df_customer = pd.read_csv('C:/Users/User/github/G_Capstone_Design/public_data/Customer_data.csv',encoding='cp949')
df_trade = pd.read_csv('C:/Users/User/github/G_Capstone_Design/public_data/Trade_data.csv',encoding='cp949')

# %%
df_industrial.head(1)
# Out:
#      시점  월별 시간별    농업    임업    어업  석탄/ 원유 및 천연가스 광업  금속 광업  비금속광물 광업;연료용 제외  \
# 0  2016  1월  1시  1096  1033  1001               642    753              482
#
#    광업 지원 서비스업  ...  교육 서비스업  보건업  사회복지 서비스업  창작/ 예술 및 여가관련 서비스업  \
# 0         753  ...      803  784       1230                 569
#
#    스포츠 및 오락관련 서비스업  협회 및 단체  개인 및 소비용품 수리업  기타 개인 서비스업  가구내 고용활동  국제 및 외국기관
# 0              731      838            413         668       444        881
#
# [1 rows x 79 columns]

# %%
df_customer.head(3)
# Out:
#      시점  항목 시간대별  데이터
# 0  2017  1월   1시  964
# 1  2017  1월   2시  851
# 2  2017  1월   3시  790

# %%
df_customer.iloc[:,0]
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2017
# 4       2017
#         ...
# 1435    2021
# 1436    2021
# 1437    2021
# 1438    2021
# 1439    2021
# Name: 시점, Length: 1440, dtype: int64

# %%
df_trade = df_trade.iloc[1:,:]

# %%
plt.plot(df_customer['시점'],df_customer['데이터'])

# %%
plt.violinplot(df_customer['데이터'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d608bc2990>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d608bf2610>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d608bfc510>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d606705790>}

# %%
plt.xcorr(df_customer['시점'],df_customer['데이터'])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 plt.xcorr(df_customer['시점'],df_customer['데이터'])
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2997, in xcorr(x, y, normed, detrend, usevlines, maxlags, data, **kwargs)
#    2993 @_copy_docstring_and_deprecators(Axes.xcorr)
#    2994 def xcorr(
#    2995         x, y, normed=True, detrend=mlab.detrend_none, usevlines=True,
#    2996         maxlags=10, *, data=None, **kwargs):
# -> 2997     return gca().xcorr(
#    2998         x, y, normed=normed, detrend=detrend, usevlines=usevlines,
#    2999         maxlags=maxlags,
#    3000         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
