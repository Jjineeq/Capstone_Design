# %%
import pandas as pd
import numpy as np
from math import *
import matplotlib.pyplot as plt
import scipy.integrate as sci
import sympy as sy
import matplotlib
from scipy.optimize import minimize
import itertools
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/user/github/Data/capstone/목적함수test.csv', encoding='cp949')

# %%
df.index = df.time

# %%
df.drop('time', inplace=True, axis = 1)

# %%
df.sum()
# Out:
# 소비량    1934.0
# 발전량    1080.0
# 요금     2540.8
# dtype: float64

# %%
((df.iloc[:,0] - df.iloc[:,1]) * df.iloc[:,2]).sum()
# Out:
# 69741.0

# %%
list(itertools.accumulate(df.iloc[:,1]))
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  60,
#  160,
#  310,
#  490,
#  640,
#  800,
#  940,
#  1010,
#  1050,
#  1080,
#  1080,
#  1080,
#  1080,
#  1080,
#  1080]

# %%
df['누적 발전량'] = list(itertools.accumulate(df.iloc[:,1]))

# %%
df.iloc[:,:3].plot(kind= 'bar', figsize=(20,10))
plt.show()

# %%
df.iloc[:,:4].plot()
plt.show()

# %%
df.iloc[:,:3].sum()
# Out:
# 소비량    1934.0
# 발전량    1080.0
# 요금     2540.8
# dtype: float64

# %%
df
# Out:
#        소비량  발전량     요금  누적 발전량
# time
# 1:00    50    0   84.8       0
# 2:00    50    0   84.8       0
# 3:00    50    0   84.8       0
# 4:00    50    0   84.8       0
# 5:00    50    0   84.8       0
# 6:00    50    0   84.8       0
# 7:00   100    0   84.8       0
# 8:00    75    0   84.8       0
# 9:00    80   10  107.0      10
# 10:00   85   50  107.0      60
# 11:00   75  100  138.0     160
# 12:00  120  150  107.0     310
# 13:00   90  180  138.0     490
# 14:00   78  150  138.0     640
# 15:00   85  160  138.0     800
# 16:00   83  140  138.0     940
# 17:00   88   70  138.0    1010
# 18:00  130   40  138.0    1050
# 19:00  120   30  107.0    1080
# 20:00  110    0  107.0    1080
# 21:00  110    0  107.0    1080
# 22:00   80    0   84.8    1080
# 23:00   75    0   84.8    1080
# 0:00    50    0   84.8    1080
